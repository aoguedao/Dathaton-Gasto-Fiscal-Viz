# %% [markdown]
# # Hola soy bacán

# %% [markdown]
# $$ x_i = 12 x^2$$

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.xkcd()
plt.plot((np.linspace(0,10,10))**2*np.exp(-np.linspace(0,10,10)))
plt.title('xkcd')
plt.show()

# %%
# Quick utility to embed the videos below
from IPython.display import YouTubeVideo
def embed_video(index, playlist='PLYCpMb24GpOC704uO9svUrihl-HY1tTJJ'):
    return YouTubeVideo('', index=index - 1, list=playlist, width=600, height=350)

# %%
# embed_video(1)

# %%
# collatz iterations using recursive function

# %%
def collatz(x,n=0):
    """returns number of iterations to arrive to 1
    for the first time
    """
    if type(x)!=int or x<1:
        raise TypeError('Enter an integer')
    else:
        if x==1:
            return n   
        if x%2==0:
            x=x/2
            if x==1:
                return n+1
            else:
                return collatz(x,n+1)
        else:
            return collatz(3*x+1,n+1)

# %%
# some plots of the collatz number of iterations required to arrive to 1
# Out:
# 25

# %%
bounces=[]
for i in range(1,10000):
    bounces.append(collatz(i))
plt.plot(bounces,'x',alpha=0.9)
plt.title('some points')
plt.show()
